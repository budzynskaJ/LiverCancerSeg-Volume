# %%
import mmcv
import matplotlib.pyplot as plt

path = "C:/Users/Użytkownik/Desktop/studia/MAGISTERKA/II sem/Projekt badawczy/projekt/data/dane/volumes/volume-6_397.png" 

equalized_path = "C:/Users/Użytkownik/Desktop/studia/MAGISTERKA/II sem/Projekt badawczy/projekt/data/dane/volumes_norm2/volume-6_397.png" 

image = mmcv.imread(path)
equalized_image = img = mmcv.imread(equalized_path)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')

plt.show()

# %%
import cv2

histogram = cv2.calcHist([image], [0], None, [256], [0, 256])

histogram2 = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])

plt.figure(figsize=(16, 8))

# tu musimy się dogadać, jak lepiej to wygląda, czy ta wersja z hostogramem czy z tym ravel()

plt.subplot(1, 2, 1)
plt.hist(image.ravel(), 256, [0, 256], color='cornflowerblue')
# plt.plot(histogram, color='cornflowerblue')
plt.title('Original Image Histogram')

plt.subplot(1, 2, 2)
plt.hist(equalized_image.ravel(), 256, [0, 256], color='cornflowerblue')
# plt.plot(histogram2, color='cornflowerblue')
plt.title('Equalized Image Histogram')

plt.show()
