# %%
import mmcv
import mmengine
import matplotlib.pyplot as plt

#path = "C:/Users/marys/Desktop/PROJEKT BADAWCZY/dane/prepared_data/volumes/volume-49_149.png" 
#path_label = "C:/Users/marys/Desktop/PROJEKT BADAWCZY/dane/prepared_data/volume_labels/segmentation-49_149.png" 
#path_seg = "C:/Users/marys/Desktop/PROJEKT BADAWCZY/dane/prepared_data/volume_labels/volume-49_149.png" 

path = "/home/budzynskaj/project/LiverCancerProject/data/d/dane/volumes_norm_final/volume-49_149.png" 
path_label = "/home/budzynskaj/project/LiverCancerProject/data/d/dane/volume_labels/segmentation-49_149.png" 
path_seg = "/home/budzynskaj/project/LiverCancerProject/data/d/dane/volume_labels/volume-49_149.png" 


# path = "C:/Users/marys/Desktop/PROJEKT BADAWCZY/dane/prepared_data/volumes/volume-113_512.png" 
# path_label = "C:/Users/marys/Desktop/PROJEKT BADAWCZY/dane/prepared_data/volume_labels/segmentation-113_512.png" 
# path_seg = "C:/Users/marys/Desktop/PROJEKT BADAWCZY/dane/prepared_data/volume_labels/volume-113_512.png" 

img = mmcv.imread(path)
print(img.shape)
plt.figure(figsize=(8, 6))
plt.imshow(mmcv.bgr2rgb(img))
plt.show()

img = mmcv.imread(path_label)
print(img.shape)
plt.figure(figsize=(8, 6))
plt.imshow(mmcv.bgr2rgb(img))
plt.show()

img = mmcv.imread(path_seg)
print(img.shape)
plt.figure(figsize=(8, 6))
plt.imshow(mmcv.bgr2rgb(img))
plt.show()
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)

# %%
data_root = '/home/budzynskaj/project/LiverCancerProject/data/d/dane'
img_dir = 'volumes_norm_final'
ann_dir = 'volume_labels'

# define class and palette for better visualization
classes = ('other', 'liver', 'lesion')
palette = [[0, 0, 0], [0, 0, 255], [255, 0, 0]]

# %%
# Let's take a look at the segmentation map we got
import matplotlib.patches as mpatches
from PIL import Image
import numpy as np

img = Image.open(path_seg)
plt.figure(figsize=(8, 6))
im = plt.imshow(np.array(img.convert('RGB')))

# create a patch (proxy artist) for every color 
patches = [mpatches.Patch(color=np.array(palette[i])/255., 
                          label=classes[i]) for i in range(3)]
# put those patched as legend-handles into the legend
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., 
           fontsize='large')

plt.show()

# %%
# split train/val/test set randomly

import os
import os.path as osp

split_dir = 'splits/deeplabv-aug'
split_file = 'volume'

mmengine.mkdir_or_exist(osp.join(data_root, split_dir))
filename_list = [osp.splitext(filename)[0] for filename in mmengine.scandir(
    osp.join(data_root, ann_dir), suffix='.png') if split_file in filename]

with open(osp.join(data_root, split_dir, 'train.txt'), 'w') as f:
    # select first 7/10 as train set
    train_length = int(len(filename_list)*70/100)
    f.writelines(line + '\n' for line in filename_list[:train_length])

with open(osp.join(data_root, split_dir, 'val.txt'), 'w') as f:
    # select next 15/100 as val set
    val_length = int(len(filename_list)*15/100)
    f.writelines(line + '\n' for line in filename_list[train_length:train_length + val_length])
    
with open(osp.join(data_root, split_dir, 'test.txt'), 'w') as f:
    # select last 15/100 as test set
    f.writelines(line + '\n' for line in filename_list[val_length:])

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset


@DATASETS.register_module()
class DeepLabvDataset(BaseSegDataset):
    METAINFO = dict(classes = classes, palette = palette)
    def __init__(self, **kwargs):
        super().__init__(img_suffix='.png', seg_map_suffix='.png', **kwargs)

# %%
from mmengine import Config
cfg = Config.fromfile('/home/budzynskaj/mmsegmentation/configs/deeplabv3/deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1024.py')
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# crop_size = (
#     512,
#     1024,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'data/cityscapes/'
# dataset_type = 'CityscapesDataset'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=False, interval=8000, type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=dict(
#             loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=19,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=101,
#         dilations=(
#             1,
#             1,
#             1,
#             2,
#         ),
#         multi_grid=(
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             2,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             1024,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dilations=(
#             1,
#             6,
#             12,
#             18,
#         ),
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=19,
#         sampler=dict(min_kept=100000, type='OHEMPixelSampler'),
#         type='ASPPHead'),
#     pretrained='open-mmlab://resnet101_v1c',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=80000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='leftImg8bit/val', seg_map_path='gtFine/val'),
#         data_root='data/cityscapes/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='CityscapesDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         2048,
#         1024,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=80000, type='IterBasedTrainLoop', val_interval=8000)
# train_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='leftImg8bit/train', seg_map_path='gtFine/train'),
#         data_root='data/cityscapes/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     2048,
#                     1024,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     1024,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='CityscapesDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             2048,
#             1024,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         1024,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='leftImg8bit/val', seg_map_path='gtFine/val'),
#         data_root='data/cityscapes/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='CityscapesDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])

# %%
# Since we use only one GPU, BN is used instead of SyncBN
# IMPORTANT
cfg.norm_cfg = dict(type='BN', device='cpu')
cfg.crop_size = (256, 256)
cfg.workers_per_gpu = 0

cfg.optimizer.type = 'AdamW'


cfg.model.data_preprocessor.size = cfg.crop_size
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.auxiliary_head.norm_cfg = cfg.norm_cfg

# modify num classes of the model in decode/auxiliary head
cfg.model.decode_head.num_classes = 3
cfg.model.auxiliary_head.loss_decode.class_weight = [1.0, 2.0, 4.0]
cfg.model.auxiliary_head.loss_decode.loss_weight = 0.6
cfg.model.auxiliary_head.num_classes = 3

# Modify dataset type and path
cfg.dataset_type = 'DeepLabvDataset'
cfg.dataset_times = 0
cfg.data_root = data_root

cfg.train_dataloader.batch_size = 8

cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='RandomResize', scale=(256, 256), ratio_range=(1.0, 1.0), keep_ratio=True),
    dict(type='RandomCrop', crop_size=cfg.crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PhotoMetricDistortion'), 
    dict(type='PackSegInputs')
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(256, 256), keep_ratio=True),
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs')
]

cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
cfg.train_dataloader.dataset.ann_file = 'splits/deeplabv-aug/train.txt'

# IMPORTANT
cfg.train_dataloader.num_workers = 0
cfg.train_dataloader.persistent_workers = False

cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.val_dataloader.dataset.ann_file = 'splits/deeplabv-aug/val.txt'

# IMPORTANT
cfg.val_dataloader.num_workers = 0
cfg.val_dataloader.persistent_workers = False

cfg.test_dataloader = cfg.val_dataloader

# Set up working dir to save files and logs.
cfg.work_dir = '/home/budzynskaj/project/LiverCancerProject/data/d/dane/workdirs/deeplabv-aug'

cfg.train_cfg.max_iters = 60000
cfg.train_cfg.val_interval = 2000
cfg.default_hooks.logger.interval = 100
cfg.default_hooks.checkpoint.interval = 1000

# Set seed to facilitate reproducing the result
cfg['randomness'] = dict(seed=0)

# Let's have a look at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '/home/budzynskaj/project/LiverCancerProject/data/d/dane'
# dataset_times = 0
# dataset_type = 'DeepLabvDataset'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=False, interval=1000, type='CheckpointHook'),
#     logger=dict(interval=100, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=dict(
#             class_weight=[
#                 1.0,
#                 2.0,
#                 4.0,
#             ],
#             loss_weight=0.6,
#             type='CrossEntropyLoss',
#             use_sigmoid=False),
#         norm_cfg=dict(device='cpu', type='BN'),
#         num_classes=3,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=101,
#         dilations=(
#             1,
#             1,
#             1,
#             2,
#         ),
#         multi_grid=(
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(device='cpu', type='BN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             2,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dilations=(
#             1,
#             6,
#             12,
#             18,
#         ),
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(device='cpu', type='BN'),
#         num_classes=3,
#         sampler=dict(min_kept=100000, type='OHEMPixelSampler'),
#         type='ASPPHead'),
#     pretrained='open-mmlab://resnet101_v1c',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(device='cpu', type='BN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='AdamW', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=80000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/deeplabv-aug/val.txt',
#         data_prefix=dict(
#             img_path='volumes_norm_final', seg_map_path='volume_labels'),
#         data_root='/home/budzynskaj/project/LiverCancerProject/data/d/dane',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='DeepLabvDataset'),
#     num_workers=0,
#     persistent_workers=False,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         256,
#         256,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=60000, type='IterBasedTrainLoop', val_interval=2000)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='splits/deeplabv-aug/train.txt',
#         data_prefix=dict(
#             img_path='volumes_norm_final', seg_map_path='volume_labels'),
#         data_root='/home/budzynskaj/project/LiverCancerProject/data/d/dane',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     1.0,
#                     1.0,
#                 ),
#                 scale=(
#                     256,
#                     256,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='DeepLabvDataset'),
#     num_workers=0,
#     persistent_workers=False,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             1.0,
#             1.0,
#         ),
#         scale=(
#             256,
#             256,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/deeplabv-aug/val.txt',
#         data_prefix=dict(
#             img_path='volumes_norm_final', seg_map_path='volume_labels'),
#         data_root='/home/budzynskaj/project/LiverCancerProject/data/d/dane',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='DeepLabvDataset'),
#     num_workers=0,
#     persistent_workers=False,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/home/budzynskaj/project/LiverCancerProject/data/d/dane/workdirs/deeplabv-aug'
# workers_per_gpu = 0

# %%
from mmengine.runner import Runner

runner = Runner.from_cfg(cfg)
# Out:
# 05/21 19:51:07 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.19 (default, Mar 20 2024, 19:58:24) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 2080 Ti
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (SUSE Linux) 7.5.0
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.9.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 05/21 19:51:07 - mmengine - INFO - Config:
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '/home/budzynskaj/project/LiverCancerProject/data/d/dane'
# dataset_times = 0
# dataset_type = 'DeepLabvDataset'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=False, interval=1000, type='CheckpointHook'),
#     logger=dict(interval=100, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=dict(
#             class_weight=[
#                 1.0,
#                 2.0,
#                 4.0,
#             ],
#             loss_weight=0.6,
#             type='CrossEntropyLoss',
#             use_sigmoid=False),
#         norm_cfg=dict(device='cpu', type='BN'),
#         num_classes=3,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=101,
#         dilations=(
#             1,
#             1,
#             1,
#             2,
#         ),
#         multi_grid=(
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(device='cpu', type='BN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             2,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dilations=(
#             1,
#             6,
#             12,
#             18,
#         ),
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(device='cpu', type='BN'),
#         num_classes=3,
#         sampler=dict(min_kept=100000, type='OHEMPixelSampler'),
#         type='ASPPHead'),
#     pretrained='open-mmlab://resnet101_v1c',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(device='cpu', type='BN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='AdamW', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=80000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/deeplabv-aug/val.txt',
#         data_prefix=dict(
#             img_path='volumes_norm_final', seg_map_path='volume_labels'),
#         data_root='/home/budzynskaj/project/LiverCancerProject/data/d/dane',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='DeepLabvDataset'),
#     num_workers=0,
#     persistent_workers=False,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         256,
#         256,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=60000, type='IterBasedTrainLoop', val_interval=2000)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='splits/deeplabv-aug/train.txt',
#         data_prefix=dict(
#             img_path='volumes_norm_final', seg_map_path='volume_labels'),
#         data_root='/home/budzynskaj/project/LiverCancerProject/data/d/dane',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     1.0,
#                     1.0,
#                 ),
#                 scale=(
#                     256,
#                     256,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='DeepLabvDataset'),
#     num_workers=0,
#     persistent_workers=False,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             1.0,
#             1.0,
#         ),
#         scale=(
#             256,
#             256,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/deeplabv-aug/val.txt',
#         data_prefix=dict(
#             img_path='volumes_norm_final', seg_map_path='volume_labels'),
#         data_root='/home/budzynskaj/project/LiverCancerProject/data/d/dane',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 256,
#                 256,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='DeepLabvDataset'),
#     num_workers=0,
#     persistent_workers=False,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/home/budzynskaj/project/LiverCancerProject/data/d/dane/workdirs/deeplabv-aug'
# workers_per_gpu = 0
# /home/budzynskaj/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /home/budzynskaj/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# /home/budzynskaj/mmsegmentation/mmseg/structures/sampler/builder.py:11: UserWarning: ``build_pixel_sampler`` would be deprecated soon, please use ``mmseg.registry.TASK_UTILS.build()``
#   warnings.warn(
# 05/21 19:51:08 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 05/21 19:51:08 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /home/budzynskaj/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:60: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %%
# start training
runner.train()
# Out:
# 05/21 19:51:09 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# 05/21 19:51:09 - mmengine - INFO - load model from: open-mmlab://resnet101_v1c
# 05/21 19:51:09 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnet101_v1c
# 05/21 19:51:09 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 05/21 19:51:09 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 05/21 19:51:09 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 05/21 19:51:09 - mmengine - INFO - Checkpoints will be saved to /home/budzynskaj/project/LiverCancerProject/data/d/dane/workdirs/deeplabv-aug.
# 05/21 19:51:37 - mmengine - INFO - Iter(train) [  100/60000]  lr: 9.9890e-03  eta: 4:33:53  time: 0.2288  data_time: 0.0891  memory: 7419  loss: 0.1188  decode.loss_ce: 0.0678  decode.acc_seg: 98.0560  aux.loss_ce: 0.0510  aux.acc_seg: 98.5905
# 05/21 19:52:00 - mmengine - INFO - Iter(train) [  200/60000]  lr: 9.9778e-03  eta: 4:10:56  time: 0.2293  data_time: 0.0887  memory: 2500  loss: 0.0816  decode.loss_ce: 0.0422  decode.acc_seg: 96.1327  aux.loss_ce: 0.0395  aux.acc_seg: 97.7476
# 05/21 19:52:22 - mmengine - INFO - Iter(train) [  300/60000]  lr: 9.9667e-03  eta: 4:02:59  time: 0.2298  data_time: 0.0889  memory: 2500  loss: 0.0586  decode.loss_ce: 0.0292  decode.acc_seg: 99.9210  aux.loss_ce: 0.0294  aux.acc_seg: 99.9210
# 05/21 19:52:45 - mmengine - INFO - Iter(train) [  400/60000]  lr: 9.9555e-03  eta: 3:58:54  time: 0.2297  data_time: 0.0884  memory: 2500  loss: 0.0706  decode.loss_ce: 0.0342  decode.acc_seg: 99.5514  aux.loss_ce: 0.0364  aux.acc_seg: 99.5195
# 05/21 19:53:08 - mmengine - INFO - Iter(train) [  500/60000]  lr: 9.9444e-03  eta: 3:56:26  time: 0.2293  data_time: 0.0878  memory: 2500  loss: 0.0529  decode.loss_ce: 0.0262  decode.acc_seg: 96.3404  aux.loss_ce: 0.0268  aux.acc_seg: 96.7165
# 05/21 19:53:31 - mmengine - INFO - Iter(train) [  600/60000]  lr: 9.9333e-03  eta: 3:54:44  time: 0.2309  data_time: 0.0893  memory: 2500  loss: 0.0445  decode.loss_ce: 0.0212  decode.acc_seg: 99.2573  aux.loss_ce: 0.0233  aux.acc_seg: 99.0162
# 05/21 19:53:54 - mmengine - INFO - Iter(train) [  700/60000]  lr: 9.9221e-03  eta: 3:53:22  time: 0.2311  data_time: 0.0893  memory: 2500  loss: 0.0395  decode.loss_ce: 0.0187  decode.acc_seg: 99.7040  aux.loss_ce: 0.0208  aux.acc_seg: 99.6531
# 05/21 19:54:18 - mmengine - INFO - Iter(train) [  800/60000]  lr: 9.9110e-03  eta: 3:52:16  time: 0.2297  data_time: 0.0878  memory: 2500  loss: 0.0384  decode.loss_ce: 0.0169  decode.acc_seg: 99.7784  aux.loss_ce: 0.0215  aux.acc_seg: 99.7505
# 05/21 19:54:41 - mmengine - INFO - Iter(train) [  900/60000]  lr: 9.8998e-03  eta: 3:51:21  time: 0.2308  data_time: 0.0887  memory: 2500  loss: 0.0649  decode.loss_ce: 0.0309  decode.acc_seg: 98.4274  aux.loss_ce: 0.0341  aux.acc_seg: 98.4741
# 05/21 19:55:04 - mmengine - INFO - Exp name: deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1024_20240521_195106
# 05/21 19:55:04 - mmengine - INFO - Iter(train) [ 1000/60000]  lr: 9.8887e-03  eta: 3:50:33  time: 0.2298  data_time: 0.0879  memory: 2500  loss: 0.0449  decode.loss_ce: 0.0199  decode.acc_seg: 99.7772  aux.loss_ce: 0.0250  aux.acc_seg: 99.6681
# 05/21 19:55:04 - mmengine - INFO - Saving checkpoint at 1000 iterations
# 05/21 19:55:28 - mmengine - INFO - Iter(train) [ 1100/60000]  lr: 9.8775e-03  eta: 3:50:49  time: 0.2315  data_time: 0.0893  memory: 2500  loss: 0.0302  decode.loss_ce: 0.0144  decode.acc_seg: 99.8508  aux.loss_ce: 0.0158  aux.acc_seg: 99.7610
# 05/21 19:55:51 - mmengine - INFO - Iter(train) [ 1200/60000]  lr: 9.8664e-03  eta: 3:50:09  time: 0.2311  data_time: 0.0891  memory: 2500  loss: 0.0311  decode.loss_ce: 0.0147  decode.acc_seg: 99.4274  aux.loss_ce: 0.0165  aux.acc_seg: 99.5441
# 05/21 19:56:14 - mmengine - INFO - Iter(train) [ 1300/60000]  lr: 9.8552e-03  eta: 3:49:28  time: 0.2312  data_time: 0.0886  memory: 2500  loss: 0.0345  decode.loss_ce: 0.0149  decode.acc_seg: 99.7141  aux.loss_ce: 0.0195  aux.acc_seg: 99.6964
# 05/21 19:56:37 - mmengine - INFO - Iter(train) [ 1400/60000]  lr: 9.8440e-03  eta: 3:48:51  time: 0.2317  data_time: 0.0890  memory: 2500  loss: 0.0446  decode.loss_ce: 0.0211  decode.acc_seg: 99.6912  aux.loss_ce: 0.0235  aux.acc_seg: 99.7129
# 05/21 19:57:00 - mmengine - INFO - Iter(train) [ 1500/60000]  lr: 9.8329e-03  eta: 3:48:19  time: 0.2311  data_time: 0.0884  memory: 2500  loss: 0.0394  decode.loss_ce: 0.0193  decode.acc_seg: 99.6561  aux.loss_ce: 0.0201  aux.acc_seg: 99.5792
# 05/21 19:57:24 - mmengine - INFO - Iter(train) [ 1600/60000]  lr: 9.8217e-03  eta: 3:47:46  time: 0.2315  data_time: 0.0889  memory: 2500  loss: 0.0430  decode.loss_ce: 0.0190  decode.acc_seg: 99.6073  aux.loss_ce: 0.0240  aux.acc_seg: 99.6130
# 05/21 19:57:47 - mmengine - INFO - Iter(train) [ 1700/60000]  lr: 9.8106e-03  eta: 3:47:12  time: 0.2311  data_time: 0.0883  memory: 2500  loss: 0.0331  decode.loss_ce: 0.0146  decode.acc_seg: 99.7171  aux.loss_ce: 0.0185  aux.acc_seg: 99.6367
# 05/21 19:58:10 - mmengine - INFO - Iter(train) [ 1800/60000]  lr: 9.7994e-03  eta: 3:46:41  time: 0.2313  data_time: 0.0887  memory: 2500  loss: 0.0385  decode.loss_ce: 0.0182  decode.acc_seg: 99.6071  aux.loss_ce: 0.0203  aux.acc_seg: 99.5840
# 05/21 19:58:33 - mmengine - INFO - Iter(train) [ 1900/60000]  lr: 9.7882e-03  eta: 3:46:11  time: 0.2306  data_time: 0.0881  memory: 2500  loss: 0.0345  decode.loss_ce: 0.0161  decode.acc_seg: 98.5987  aux.loss_ce: 0.0184  aux.acc_seg: 98.4301
# 05/21 19:58:56 - mmengine - INFO - Exp name: deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1
- mmengine - INFO - Iter(val) [8795/8795]    aAcc: 99.4800  mIoU: 60.0900  mAcc: 63.2800  data_time: 0.0012  time: 0.0150
# 05/21 20:01:32 - mmengine - INFO - Iter(train) [ 2100/60000]  lr: 9.7659e-03  eta: 3:45:13  time: 0.2304  data_time: 0.0876  memory: 2501  loss: 0.0282  decode.loss_ce: 0.0139  decode.acc_seg: 99.8377  aux.loss_ce: 0.0143  aux.acc_seg: 99.8617
# 05/21 20:01:56 - mmengine - INFO - Iter(train) [ 2200/60000]  lr: 9.7547e-03  eta: 3:44:44  time: 0.2308  data_time: 0.0881  memory: 2500  loss: 0.0271  decode.loss_ce: 0.0126  decode.acc_seg: 99.6403  aux.loss_ce: 0.0145  aux.acc_seg: 99.5155
# 05/21 20:02:19 - mmengine - INFO - Iter(train) [ 2300/60000]  lr: 9.7436e-03  eta: 3:44:16  time: 0.2309  data_time: 0.0880  memory: 2500  loss: 0.0194  decode.loss_ce: 0.0090  decode.acc_seg: 99.8486  aux.loss_ce: 0.0104  aux.acc_seg: 99.7719
# 05/21 20:02:42 - mmengine - INFO - Iter(train) [ 2400/60000]  lr: 9.7324e-03  eta: 3:43:49  time: 0.2316  data_time: 0.0889  memory: 2500  loss: 0.0180  decode.loss_ce: 0.0082  decode.acc_seg: 99.8539  aux.loss_ce: 0.0098  aux.acc_seg: 99.8550
# 05/21 20:03:05 - mmengine - INFO - Iter(train) [ 2500/60000]  lr: 9.7212e-03  eta: 3:43:23  time: 0.2312  data_time: 0.0884  memory: 2500  loss: 0.0234  decode.loss_ce: 0.0115  decode.acc_seg: 99.6592  aux.loss_ce: 0.0120  aux.acc_seg: 99.6092
# 05/21 20:03:28 - mmengine - INFO - Iter(train) [ 2600/60000]  lr: 9.7101e-03  eta: 3:42:56  time: 0.2318  data_time: 0.0892  memory: 2500  loss: 0.0258  decode.loss_ce: 0.0121  decode.acc_seg: 100.0000  aux.loss_ce: 0.0137  aux.acc_seg: 100.0000
# 05/21 20:03:51 - mmengine - INFO - Iter(train) [ 2700/60000]  lr: 9.6989e-03  eta: 3:42:30  time: 0.2307  data_time: 0.0878  memory: 2500  loss: 0.0214  decode.loss_ce: 0.0099  decode.acc_seg: 99.8495  aux.loss_ce: 0.0115  aux.acc_seg: 99.8276
# 05/21 20:04:14 - mmengine - INFO - Iter(train) [ 2800/60000]  lr: 9.6877e-03  eta: 3:42:04  time: 0.2321  data_time: 0.0891  memory: 2500  loss: 0.0289  decode.loss_ce: 0.0140  decode.acc_seg: 99.8482  aux.loss_ce: 0.0149  aux.acc_seg: 99.8293
# 05/21 20:04:38 - mmengine - INFO - Iter(train) [ 2900/60000]  lr: 9.6765e-03  eta: 3:41:38  time: 0.2328  data_time: 0.0899  memory: 2500  loss: 0.0303  decode.loss_ce: 0.0137  decode.acc_seg: 99.7869  aux.loss_ce: 0.0166  aux.acc_seg: 99.7044
# 05/21 20:05:01 - mmengine - INFO - Exp name: deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1024_20240521_195106
# 05/21 20:05:01 - mmengine - INFO - Iter(train) [ 3000/60000]  lr: 9.6653e-03  eta: 3:41:13  time: 0.2308  data_time: 0.0881  memory: 2500  loss: 0.0275  decode.loss_ce: 0.0133  decode.acc_seg: 99.0843  aux.loss_ce: 0.0142  aux.acc_seg: 99.2510
# 05/21 20:05:01 - mmengine - INFO - Saving checkpoint at 3000 iterations
# 05/21 20:05:25 - mmengine - INFO - Iter(train) [ 3100/60000]  lr: 9.6542e-03  eta: 3:41:10  time: 0.2319  data_time: 0.0894  memory: 2500  loss: 0.0211  decode.loss_ce: 0.0097  decode.acc_seg: 99.4751  aux.loss_ce: 0.0114  aux.acc_seg: 99.4131
# 05/21 20:05:48 - mmengine - INFO - Iter(train) [ 3200/60000]  lr: 9.6430e-03  eta: 3:40:45  time: 0.2315  data_time: 0.0888  memory: 2500  loss: 0.0274  decode.loss_ce: 0.0131  decode.acc_seg: 99.9523  aux.loss_ce: 0.0143  aux.acc_seg: 99.9350
# 05/21 20:06:12 - mmengine - INFO - Iter(train) [ 3300/60000]  lr: 9.6318e-03  eta: 3:40:19  time: 0.2327  data_time: 0.0899  memory: 2500  loss: 0.0215  decode.loss_ce: 0.0100  decode.acc_seg: 99.8640  aux.loss_ce: 0.0115  aux.acc_seg: 99.8438
# 05/21 20:06:35 - mmengine - INFO - Iter(train) [ 3400/60000]  lr: 9.6206e-03  eta: 3:39:54  time: 0.2324  data_time: 0.0897  memory: 2500  loss: 0.0178  decode.loss_ce: 0.0084  decode.acc_seg: 99.9275  aux.loss_ce: 0.0093  aux.acc_seg: 99.9491
# 05/21 20:06:58 - mmengine - INFO - Iter(train) [ 3500/60000]  lr: 9.6094e-03  eta: 3:39:29  time: 0.2316  data_time: 0.0888  memory: 2500  loss: 0.0275  decode.loss_ce: 0.0122  decode.acc_seg: 99.7980  aux.loss_ce: 0.0152  aux.acc_seg: 99.8167
# 05/21 20:07:21 - mmengine - INFO - Iter(train) [ 3600/60000]  lr: 9.5982e-03  eta: 3:39:04  time: 0.2334  data_time: 0.0906  memory: 2500  loss: 0.0268  decode.loss_ce: 0.0127  decode.acc_seg: 99.0301  aux.loss_ce: 0.0141  aux.acc_seg: 99.1167
# 05/21 20:07:44 - mmengine - INFO - Iter(train) [ 3700/60000]  lr: 9.5870e-03  eta: 3:38:39  time: 0.2321  data_time: 0.0892  memory: 2500  loss: 0.0316  decode.loss_ce: 0.0155  decode.acc_seg: 99.4513  aux.loss_ce: 0.0161  aux.acc_seg: 99.4270
# 05/21 20:08:08 - mmengine - INFO - Iter(train) [ 3800/60000]  lr: 9.5759e-03  eta: 3:38:13  time: 0.2322  data_time: 0.0893  memory: 2500  loss: 0.0190  decode.loss_ce: 0.0089  decode.acc_seg: 99.6088  aux.loss_ce: 0.0100  aux.acc_seg: 99.5764
# 05/21 20:08:31 - mmengine - INFO - Iter(train) [ 3900/60000]  lr: 9.5647e-03  eta: 3:37:47  time: 0.2308  data_time: 0.0878  memory: 2500  loss: 0.0175  decode.loss_ce: 0.0086  decode.acc_seg: 99.4581  aux.loss_ce: 0.0089  aux.acc_seg: 99.4911
# 05/21 20:08:54 - mmengine - INFO - Exp name: deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1
time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:11:02 - mmengine - INFO - Iter(val) [8400/8795]    eta: 0:00:05  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:11:03 - mmengine - INFO - Iter(val) [8500/8795]    eta: 0:00:04  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:11:05 - mmengine - INFO - Iter(val) [8600/8795]    eta: 0:00:02  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:11:06 - mmengine - INFO - Iter(val) [8700/8795]    eta: 0:00:01  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:11:08 - mmengine - INFO - per class results:
# 05/21 20:11:08 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# | other  | 99.61 | 99.83 |
# | liver  | 83.77 | 90.87 |
# | lesion | 28.97 | 33.97 |
# +--------+-------+-------+
# 05/21 20:11:08 - mmengine - INFO - Iter(val) [8795/8795]    aAcc: 99.5700  mIoU: 70.7800  mAcc: 74.8900  data_time: 0.0012  time: 0.0150
# 05/21 20:11:31 - mmengine - INFO - Iter(train) [ 4100/60000]  lr: 9.5423e-03  eta: 3:36:58  time: 0.2315  data_time: 0.0885  memory: 2500  loss: 0.0262  decode.loss_ce: 0.0128  decode.acc_seg: 99.7679  aux.loss_ce: 0.0133  aux.acc_seg: 99.7437
# 05/21 20:11:54 - mmengine - INFO - Iter(train) [ 4200/60000]  lr: 9.5311e-03  eta: 3:36:33  time: 0.2325  data_time: 0.0895  memory: 2500  loss: 0.0241  decode.loss_ce: 0.0114  decode.acc_seg: 99.6759  aux.loss_ce: 0.0128  aux.acc_seg: 99.5424
# 05/21 20:12:17 - mmengine - INFO - Iter(train) [ 4300/60000]  lr: 9.5199e-03  eta: 3:36:08  time: 0.2319  data_time: 0.0890  memory: 2500  loss: 0.0186  decode.loss_ce: 0.0094  decode.acc_seg: 99.7906  aux.loss_ce: 0.0092  aux.acc_seg: 99.8543
# 05/21 20:12:40 - mmengine - INFO - Iter(train) [ 4400/60000]  lr: 9.5087e-03  eta: 3:35:43  time: 0.2314  data_time: 0.0886  memory: 2500  loss: 0.0151  decode.loss_ce: 0.0077  decode.acc_seg: 99.8579  aux.loss_ce: 0.0074  aux.acc_seg: 99.8661
# 05/21 20:13:03 - mmengine - INFO - Iter(train) [ 4500/60000]  lr: 9.4975e-03  eta: 3:35:18  time: 0.2327  data_time: 0.0897  memory: 2500  loss: 0.0145  decode.loss_ce: 0.0067  decode.acc_seg: 99.8543  aux.loss_ce: 0.0079  aux.acc_seg: 99.8156
# 05/21 20:13:27 - mmengine - INFO - Iter(train) [ 4600/60000]  lr: 9.4863e-03  eta: 3:34:54  time: 0.2322  data_time: 0.0895  memory: 2500  loss: 0.0310  decode.loss_ce: 0.0138  decode.acc_seg: 99.1535  aux.loss_ce: 0.0172  aux.acc_seg: 99.2779
# 05/21 20:13:50 - mmengine - INFO - Iter(train) [ 4700/60000]  lr: 9.4751e-03  eta: 3:34:29  time: 0.2309  data_time: 0.0883  memory: 2500  loss: 0.0149  decode.loss_ce: 0.0073  decode.acc_seg: 99.7162  aux.loss_ce: 0.0076  aux.acc_seg: 99.6914
# 05/21 20:14:13 - mmengine - INFO - Iter(train) [ 4800/60000]  lr: 9.4639e-03  eta: 3:34:04  time: 0.2319  data_time: 0.0891  memory: 2500  loss: 0.0175  decode.loss_ce: 0.0084  decode.acc_seg: 99.7925  aux.loss_ce: 0.0091  aux.acc_seg: 99.7515
# 05/21 20:14:36 - mmengine - INFO - Iter(train) [ 4900/60000]  lr: 9.4527e-03  eta: 3:33:39  time: 0.2304  data_time: 0.0875  memory: 2500  loss: 0.0224  decode.loss_ce: 0.0108  decode.acc_seg: 99.1127  aux.loss_ce: 0.0116  aux.acc_seg: 98.9676
# 05/21 20:14:59 - mmengine - INFO - Exp name: deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1024_20240521_195106
# 05/21 20:14:59 - mmengine - INFO - Iter(train) [ 5000/60000]  lr: 9.4414e-03  eta: 3:33:14  time: 0.2306  data_time: 0.0878  memory: 2500  loss: 0.0150  decode.loss_ce: 0.0075  decode.acc_seg: 99.8285  aux.loss_ce: 0.0074  aux.acc_seg: 99.8466
# 05/21 20:14:59 - mmengine - INFO - Saving checkpoint at 5000 iterations
# 05/21 20:15:23 - mmengine - INFO - Iter(train) [ 5100/60000]  lr: 9.4302e-03  eta: 3:33:00  time: 0.2313  data_time: 0.0888  memory: 2500  loss: 0.0165  decode.loss_ce: 0.0079  decode.acc_seg: 99.4274  aux.loss_ce: 0.0087  aux.acc_seg: 99.4392
# 05/21 20:15:30 - mmengine - INFO - Exp name: deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1024_20240521_195106
# 05/21 20:15:46 - mmengine - INFO - Iter(train) [ 5200/60000]  lr: 9.4190e-03  eta: 3:32:36  time: 0.2322  data_time: 0.0893  memory: 2500  loss: 0.0168  decode.loss_ce: 0.0080  decode.acc_seg: 100.0000  aux.loss_ce: 0.0088  aux.acc_seg: 100.0000
# 05/21 20:16:10 - mmengine - INFO - Iter(train) [ 5300/60000]  lr: 9.4078e-03  eta: 3:32:11  time: 0.2305  data_time: 0.0877  memory: 2500  loss: 0.0133  decode.loss_ce: 0.0066  decode.acc_seg: 99.7719  aux.loss_ce: 0.0067  aux.acc_seg: 99.7393
# 05/21 20:16:33 - mmengine - INFO - Iter(train) [ 5400/60000]  lr: 9.3966e-03  eta: 3:31:46  time: 0.2310  data_time: 0.0879  memory: 2500  loss: 0.0198  decode.loss_ce: 0.0094  decode.acc_seg: 99.5199  aux.loss_ce: 0.0105  aux.acc_seg: 99.3944
# 05/21 20:16:56 - mmengine - INFO - Iter(train) [ 5500/60000]  lr: 9.3854e-03  eta: 3:31:22  time: 0.2322  data_time: 0.0893  memory: 2500  loss: 0.0219  decode.loss_ce: 0.0110  decode.acc_seg: 99.1037  aux.loss_ce: 0.0109  aux.acc_seg: 99.0669
# 05/21 20:17:19 - mmengine - INFO - Iter(train) [ 5600/60000]  lr: 9.3742e-03  eta: 3:30:57  time: 0.2331  data_time: 0.0902  memory: 2500  loss: 0.0186  decode.loss_ce: 0.0090  decode.acc_seg: 99.7908  aux.loss_ce: 0.0097  aux.acc_seg: 99.6750
# 05/21 20:17:42 - mmengine - INFO - Iter(train) [ 5700/60000]  lr: 9.3629e-03  eta: 3:30:33  time: 0.2329  data_time: 0.0900  memory: 2500  loss: 0.0187  decode.loss_ce: 0.0089  decode.acc_seg: 99.7396  aux.loss_ce: 0.0098  aux.acc_seg: 99.6935
# 05/21 20:18:05 - mmengine - INFO - Iter(train) [ 5800/60000]  lr: 9.3517e-03  eta: 3:30:09  time: 0.2314  data_time: 0.0884  memory: 2500  loss: 0.0102  decode.loss_ce: 0.0049  decode.acc_seg: 99.9847  aux.loss_ce: 0.0052  aux.acc_seg: 99.9847
# 05/21 20:18:28 - mmengine - INFO - Iter(train) [ 5900/60000]  lr: 9.3405e-03  eta: 3:29:45  time: 0.2324  data_time: 0.0895  memory: 2500  loss: 0.0217  decode.loss_ce: 0.0104  decode.acc_seg: 99.1669  aux.loss_ce: 0.0113  aux.acc_seg: 99.1598
# 05/21 20:18:52 - mmengine - INFO - Exp name: deeplabv3_r101-d16-mg124_4xb2-80k_cityscapes-512x1024_20240521_195106
# 05/21 20:18:52 - mmengine - INFO - Iter(train) [ 6000/60000]  lr: 9.3293e-03  eta: 3:29:21  time: 0.2305  data_time: 0.0876  memory: 2500  loss: 0.0185  decode.loss_ce: 0.0093  decode.acc_seg: 99.4135  aux.loss_ce: 0.0092  aux.acc_seg: 99.2485
# 05/21 20:18:52 - mmengine - INFO - Saving checkpoint at 6000 iterations
# 05/21 20:18:54 - mmengine - INFO - Iter(val) [ 100/8795]    eta: 0:02:13  time: 0.0151  data_time: 0.0012  memory: 808
# 05/21 20:18:56 - mmengine - INFO - Iter(val) [ 200/8795]    eta: 0:02:10  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:18:57 - mmengine - INFO - Iter(val) [ 300/8795]    eta: 0:02:09  time: 0.0151  data_time: 0.0012  memory: 808
# 05/21 20:18:59 - mmengine - INFO - Iter(val) [ 400/8795]    eta: 0:02:07  time: 0.0151  data_time: 0.0012  memory: 808
# 05/21 20:19:00 - mmengine - INFO - Iter(val) [ 500/8795]    eta: 0:02:05  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:19:02 - mmengine - INFO - Iter(val) [ 600/8795]    eta: 0:02:04  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:19:03 - mmengine - INFO - Iter(val) [ 700/8795]    eta: 0:02:02  time: 0.0149  data_time: 0.0012  memory: 808
# 05/21 20:19:05 - mmengine - INFO - Iter(val) [ 800/8795]    eta: 0:02:00  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:19:06 - mmengine - INFO - Iter(val) [ 900/8795]    eta: 0:01:59  time: 0.0149  data_time: 0.0012  memory: 808
# 05/21 20:19:08 - mmengine - INFO - Iter(val) [1000/8795]    eta: 0:01:57  time: 0.0151  data_time: 0.0013  memory: 808
# 05/21 20:19:09 - mmengine - INFO - Iter(val) [1100/8795]    eta: 0:01:56  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:19:11 - mmengine - INFO - Iter(val) [1200/8795]    eta: 0:01:54  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:19:12 - mmengine - INFO - Iter(val) [1300/8795]    eta: 0:01:52  time: 0.0149  data_time: 0.0011  memory: 808
# 05/21 20:19:14 - mmengine - INFO - Iter(val) [1400/8795]    eta: 0:01:51  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:19:15 - mmengine - INFO - Iter(val) [1500/8795]    eta: 0:01:49  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:19:17 - mmengine - INFO - Iter(val) [1600/8795]    eta: 0:01:48  time: 0.0149  data_time: 0.0011  memory: 808
# 05/21 20:19:18 - mmengine - INFO - Iter(val) [1700/8795]    eta: 0:01:46  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:19
time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:14 - mmengine - INFO - Iter(val) [5400/8795]    eta: 0:00:51  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:16 - mmengine - INFO - Iter(val) [5500/8795]    eta: 0:00:49  time: 0.0151  data_time: 0.0012  memory: 808
# 05/21 20:20:17 - mmengine - INFO - Iter(val) [5600/8795]    eta: 0:00:48  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:19 - mmengine - INFO - Iter(val) [5700/8795]    eta: 0:00:46  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:20 - mmengine - INFO - Iter(val) [5800/8795]    eta: 0:00:45  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:22 - mmengine - INFO - Iter(val) [5900/8795]    eta: 0:00:43  time: 0.0151  data_time: 0.0012  memory: 808
# 05/21 20:20:23 - mmengine - INFO - Iter(val) [6000/8795]    eta: 0:00:42  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:25 - mmengine - INFO - Iter(val) [6100/8795]    eta: 0:00:40  time: 0.0153  data_time: 0.0013  memory: 808
# 05/21 20:20:26 - mmengine - INFO - Iter(val) [6200/8795]    eta: 0:00:39  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:28 - mmengine - INFO - Iter(val) [6300/8795]    eta: 0:00:37  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:29 - mmengine - INFO - Iter(val) [6400/8795]    eta: 0:00:36  time: 0.0151  data_time: 0.0013  memory: 808
# 05/21 20:20:31 - mmengine - INFO - Iter(val) [6500/8795]    eta: 0:00:34  time: 0.0151  data_time: 0.0012  memory: 808
# 05/21 20:20:32 - mmengine - INFO - Iter(val) [6600/8795]    eta: 0:00:33  time: 0.0149  data_time: 0.0011  memory: 808
# 05/21 20:20:34 - mmengine - INFO - Iter(val) [6700/8795]    eta: 0:00:31  time: 0.0151  data_time: 0.0012  memory: 808
# 05/21 20:20:35 - mmengine - INFO - Iter(val) [6800/8795]    eta: 0:00:30  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:37 - mmengine - INFO - Iter(val) [6900/8795]    eta: 0:00:28  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:39 - mmengine - INFO - Iter(val) [7000/8795]    eta: 0:00:27  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:40 - mmengine - INFO - Iter(val) [7100/8795]    eta: 0:00:25  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:42 - mmengine - INFO - Iter(val) [7200/8795]    eta: 0:00:24  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:43 - mmengine - INFO - Iter(val) [7300/8795]    eta: 0:00:22  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:45 - mmengine - INFO - Iter(val) [7400/8795]    eta: 0:00:21  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:46 - mmengine - INFO - Iter(val) [7500/8795]    eta: 0:00:19  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:48 - mmengine - INFO - Iter(val) [7600/8795]    eta: 0:00:18  time: 0.0150  data_time: 0.0012  memory: 808
# 05/21 20:20:49 - mmengine - INFO - Iter(val) [7700/8795]    eta: 0:00:16  time: 0.0150  data_time: 0.0012  memory: 808
# ...
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet101_v1c'}
#   (decode_head): ASPPHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(512, 3, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (image_pool): Sequential(
#       (0): AdaptiveAvgPool2d(output_size=1)
#       (1): ConvModule(
#         (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#     (aspp_modules): ASPPModule(
#       (0): ConvModule(
#         (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#       (1): ConvModule(
#         (conv): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#       (2): ConvModule(
#         (conv): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#       (3): ConvModule(
#         (conv): Conv2d(2048, 512, kernel_size=(3, 3), stride=(1, 1), padding=(18, 18), dilation=(18, 18), bias=False)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#     (bottleneck): ConvModule(
#       (conv): Conv2d(2560, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot
import mmcv

# Init the model from the config and the checkpoint
checkpoint_path = '/home/budzynskaj/project/LiverCancerProject/data/d/dane/workdirs/deeplabv-aug/iter_46000.pth'
config = '/home/budzynskaj/project/LiverCancerProject/data/d/dane/workdirs/deeplabv/20240516_222335/vis_data/config.py'
model = init_model(cfg, checkpoint_path, device=None)

img = mmcv.imread(path)
result = inference_model(model, img)
plt.figure(figsize=(8, 6))
vis_result = show_result_pyplot(model, img, result)
plt.imshow(mmcv.bgr2rgb(vis_result))
# Out:
# /home/budzynskaj/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# /home/budzynskaj/mmsegmentation/mmseg/structures/sampler/builder.py:11: UserWarning: ``build_pixel_sampler`` would be deprecated soon, please use ``mmseg.registry.TASK_UTILS.build()``
#   warnings.warn(
# Loads checkpoint by local backend from path: /home/budzynskaj/project/LiverCancerProject/data/d/dane/workdirs/deeplabv-aug/iter_46000.pth
# /home/budzynskaj/miniconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
